# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
plt.plot([3, -5, 2, 7, 10, -9])

# %%
y = [3, -5, 2, 7, 10, -9]
x = [0, 0.7, 3, 4.2, 7, 10]

# %%
plt.plot(x, y)

# %%
plt.scatter(x, y)

# %% [markdown]
# markdown
# #大標題
# ##第二大標題

# %% [markdown]
# 快速轉換markdown
# control m
# [python](http://opus.konghy.cn/ipynb/jupyter-notebook-keyboard-shortcut.html)

# %% [markdown]
# ![圖](abc.jpeg)

# %% [markdown]
# 假設我們有個函數$f(x)=x^3-2x^2+5$
# $$L = \int_a^bx^3+5$$

# %% [markdown]
# # 畫個函數
# $f(x)=cos(x)$

# %%
x= np.linspace(-10, 10, 100)

# %%
y = np.cos(x)

# %%
plt.plot(x,y)

# %%
x= np.linspace(-5, 5, 1000)
y = np.cos(x)
plt.plot(x,y)

# %%
x= np.linspace(-30, 30, 1000)
y = np.cos(x)
plt.plot(x,y)
x2= np.linspace(-30, 30, 1000)
y2 = np.sin(x2)
plt.plot(x2,y2)
x3= np.linspace(-30, 30, 1000)
y3 = np.sin(x2+1)
plt.plot(x3,y3)
